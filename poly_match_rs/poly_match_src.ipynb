# %% [markdown]
# # Poly Match (src Rust)
#
# Ce notebook sert à explorer les sources Rust et à lancer la compilation.
#
# Commandes utiles (à exécuter via des cellules shell):
# - `!maturin develop --release`
# - `!cargo test` (si des tests sont ajoutés)
#
# Note: redémarrer le kernel des notebooks Python après recompilation.

# %%
# Compilation du module pour Python
maturin develop --release | cat

# %%
# Aperçu rapide des fichiers Rust
import os, textwrap
base = "src"
for fname in ["lib_v0.rs","lib_v1.rs","lib_v2.rs","lib_v3.rs","lib_v4.rs","lib.rs"]:
    path = os.path.join(base, fname)
    if os.path.exists(path):
        print(f"\n=== {path} ===")
        with open(path, "r") as f:
            content = f.read().splitlines()
        # Affiche les ~80 premières lignes pour donner une idée
        print("\n".join(content[:80]))
